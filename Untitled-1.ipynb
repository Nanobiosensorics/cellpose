# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import fastremap
import tifffile
import os
from sys import getsizeof
import time
from cellpose.io import save_masks, imread
from cellpose.utils import diameters
from data_loader import CellDataLoader, CellDataset
from time import time
import os, psutil
from tqdm import tqdm
process = psutil.Process(os.getpid())

# %%
seg = imread('data/train/A1_0_0_seg.npy')
mask = imread('data/train/etc/A1_0_0_cp_masks.png')
flows = imread('data/train/A1_0_0_flows.tif')

# %%
seg.shape, mask.shape, flows.shape
# Out:
# ((2635, 3037), (2635, 3037), (4, 2635, 3037))

# %%
fig, ax = plt.subplots(1,3, figsize=(15,15))
ax[0].imshow(seg)
ax[1].imshow(mask)
ax[2].imshow(flows[0])
plt.show()

# %%
df = seg - flows[0]

# %%
diameters(seg)[0], diameters(flows[0])[0]
# Out:
# (78.14382161469864, 78.14382161469864)

# %%
train_ds = CellDataset('data', load_seg=False, train=True)
# Out:
# ['data/train/A1_1_0.png', 'data/train/A1_0_1.png', 'data/train/A1_1_1.png', 'data/train/A1_0_0.png']
# ['data/train/A1_1_0_seg.npy', 'data/train/A1_0_1_seg.npy', 'data/train/A1_1_1_seg.npy', 'data/train/A1_0_0_seg.npy']
# ['data/train/A1_1_0_flows.tif', 'data/train/A1_0_1_flows.tif', 'data/train/A1_1_1_flows.tif', 'data/train/A1_0_0_flows.tif']

# %%
img, target = train_ds[-1]
# Out:
# 100%|███████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.96s/it]

# %%
print(process.memory_info().rss / 1024**2)
# Out:
# 758.71875

# %%
img.shape, target.shape
# Out:
# (torch.Size([2, 224, 224]), torch.Size([3, 224, 224]))

# %%
train_loader = CellDataLoader('data', batch_size=5, shuffle=False)

# %%
[diameters(train_ds.load_raw(k)[1][0])[0] for k in range(len(train_ds))]
# Out:
# ...
# 100%|███████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.94s/it]
# [78.14382161469864, 76.96437845010891, 75.91233219623375, 79.08894627047063]

# %%
ds = train_ds[1][1][0]

# %%
for data in train_ds:
    plt.figure()
    fig, ax = plt.subplots(1, 4)
    ax[0].imshow(data[0][0])
    for i in range(1,4):
        ax[i].imshow(data[1][0])
    plt.show()

# %%
start = time()
with tqdm(train_loader) as t_loader:
    for i, (data, target) in enumerate(t_loader):
        t_loader.set_description(f"Iter {i}")
        print(data.shape, target.shape)
        print(time() - start, process.memory_info().rss / 1024**2)
        t_loader.set_postfix({'after': i})
# Out:
# Iter 0:  33%|████████████▋                         | 1/3 [00:07<00:14,  7.40s/it, after=0]
# torch.Size([5, 2, 224, 224]) torch.Size([5, 3, 224, 224])
# 7.401859521865845 203.30078125
# Iter 0:  33%|████████████▋                         | 1/3 [00:12<00:25, 12.57s/it, after=0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 start = time()
#       2 with tqdm(train_loader) as t_loader:
# ----> 3     for i, (data, target) in enumerate(t_loader):
#       4         t_loader.set_description(f"Iter {i}")
#       5         print(data.shape, target.shape)
#
# File ~/anaconda3/envs/cellpose/lib/python3.8/site-packages/tqdm/std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
# ...

# %%
def imread(filename):
    """ read in image with tif or image file type supported by cv2 """
    # ensure that extension check is not case sensitive
    ext = os.path.splitext(filename)[-1].lower()
    if ext== '.tif' or ext=='.tiff':
        with tifffile.TiffFile(filename) as tif:
            ltif = len(tif.pages)
            try:
                full_shape = tif.shaped_metadata[0]['shape']
            except:
                try:
                    page = tif.series[0][0]
                    full_shape = tif.series[0].shape
                except:
                    ltif = 0
            if ltif < 10:
                img = tif.asarray()
            else:
                page = tif.series[0][0]
                shape, dtype = page.shape, page.dtype
                ltif = int(np.prod(full_shape) / np.prod(shape))
                img = np.zeros((ltif, *shape), dtype=dtype)
                for i,page in enumerate(tqdm(tif.series[0])):
                    img[i] = page.asarray()
                img = img.reshape(full_shape)            
        return img
    elif ext != '.npy':
        try:
            img = cv2.imread(filename, -1)#cv2.LOAD_IMAGE_ANYDEPTH)
            if img.ndim > 2:
                img = img[..., [2,1,0]]
            return img
        except Exception as e:
            return None
    else:
        try:
            dat = np.load(filename, allow_pickle=True).item()
            masks = dat['masks']
            return masks
        except Exception as e:
            return None

# %%
paths = [ pth for pth in os.listdir('data') if '_seg.npy' in pth ]
names = [ '_'.join(pth.split('_')[:-1]) for pth in paths ]

# %%
d = imread(os.path.join('data', names[0] + '_flows.tif'))

# %%
plt.imshow(d[3])

# %%
segs = []
for name in names:
    im = imread(os.path.join('data', name + '.png'))
    masks = imread(os.path.join('data', name + '_seg.npy'))
    save_masks(im, masks, None, name, savedir='data', save_flows=False, save_outlines=False, save_txt=False)

# %%
nbytes = 0
for pth, obj in segs:
    nbytes += obj.nbytes
nbytes / 1024 / 1024
# Out:
# 250.11259651184082

# %%
segs[0][1].shape
# Out:
# (2672, 2746)

# %%
start = time.time()
im = imread('data/A4_1_1_cp_masks.png')
time.time() - start
# Out:
# 0.07031488418579102

# %%
im.shape[0] * im.shape[1] / 1024 / 1024
# Out:
# 7.877023696899414

# %%
im.nbytes / 1024**2
# Out:
# 15.754047393798828

# %%
masks = imread('A1_0_0_cp_flows.tif')
outlines = None
if masks.ndim>3:
    # Z x nchannels x Ly x Lx
    if masks.shape[-1]>5:
        # parent.flows = list(np.transpose(masks[:,:,:,2:], (3,0,1,2)))
        outlines = masks[...,1]
        masks = masks[...,0]
    else:
        # parent.flows = list(np.transpose(masks[:,:,:,1:], (3,0,1,2)))
        masks = masks[...,0]
elif masks.ndim==3:
    print('load==3')
    if masks.shape[-1]<5:
        masks = masks[np.newaxis,:,:,0]
elif masks.ndim<3:
    print('load<3')
    masks = masks[np.newaxis,:,:]
    

shape = masks.shape
masks = masks.flatten()
fastremap.renumber(masks, in_place=True)
masks = masks.reshape(shape)
masks = masks.astype(np.uint16) if masks.max()<2**16-1 else masks.astype(np.uint32)
print(f'GUI_INFO: {masks.max()} masks found')
# Out:
# load<3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 18
#      16 elif masks.ndim<3:
#      17     print('load<3')
# ---> 18     masks = masks[np.newaxis,:,:]
#      21 shape = masks.shape
#      22 masks = masks.flatten()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
im.shape
# Out:
# (2635, 3037)

# %%
plt.imshow(im)
